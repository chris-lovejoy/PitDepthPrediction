# %% [markdown]
# # Outline of functions used in the training data pipeline

# %% [markdown]
# ## This notebook demo's the pipeline for converting the feature data frame into a training and test set that can be used in testing models. Our models were ultimately built using cross-validation rather than the techniques outlined here. However, there are still many functions here that may be useful, especially for quick testing purposes.

# %%
import os
import pandas as pd
import random
import sys
from math import sqrt
from sklearn import svm
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ###### set the path

# %%
sys.path.insert(0,os.path.dirname(os.getcwd()))
import src.models.modeling_pipeline as mp

# %% [markdown]
# ##### import the data

# %%
data_path = os.path.join(os.path.dirname(os.getcwd()),'data', 'interim', 'full_feature_cg_data.csv')
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#   Tube_Alias Flaw_ID  Angle      Amp_1      Amp_2      Amp_3      Amp_4  \
# 0       AP01       A      0  10.320653  14.854606  16.017633  12.423161
# 1       AP01       A     10   9.256762  13.566036  12.946058  12.594721
# 2       AP01       A     20   6.375396   8.061063   9.746397  10.879743
# 3       AP01       A     30   9.700410  11.746437  14.777542  16.300598
# 4       AP01       A     40   7.913722  10.297010  10.453795  10.156999
#
#        Amp_5      Amp_6      Amp_7  ...  Phase_15  Phase_16  Phase_17  \
# 0  23.971155  18.113805  36.668613  ...  0.330427 -0.038826 -0.681307
# 1  19.365281  17.401339  28.518174  ...  0.290231 -0.069128 -0.695486
# 2  14.309066  18.105114  22.923653  ...  0.355075 -0.013229 -0.505109
# 3  18.984767  21.744765  30.582848  ...  0.338012 -0.003931 -0.437232
# 4  15.417897  17.797726  26.734713  ...  0.372874 -0.057453 -0.440830
#
#    Phase_18  Phase_19  Phase_20  Flaw_Depth  Pct_Depth  Flaw_Volume  Flaw_Area
# 0 -0.840659  0.556654  0.333518       0.076       10.3        0.864    11.3288
# 1 -0.739280  0.548302  0.294714       0.076       10.3        0.864    11.3288
# 2 -0.781582  0.626245  0.293746       0.076       10.3        0.864    11.3288
# 3 -0.721585  0.560389  0.277560       0.076       10.3        0.864    11.3288
# 4 -0.200000  0.514553  0.194392       0.076       10.3        0.864    11.3288
#
# [5 rows x 47 columns]

# %% [markdown]
# #### The data pipeline is intended to transform the data above into scaled X_train and X_test matrices, and y_train and y_test vectors

# %%
X_train, X_test, y_train, y_test, train, test = mp.get_scaled_training_test_data(df)

# %% [markdown]
# ##### This module includes a number of functions that are integrated into the driver function above. Here, they will be outlined to clarify what the the driver function is actually doing.

# %% [markdown]
# ##### The first function is subset_data_with_features, which takes a dataframe and, optionally, a feature list as arguments. If no list is passed to this function, it returns the dataframe with all amp/phase features, the ID info, and the flaw depth.

# %%
new_df1 = mp.subset_data_with_features(df)
new_df1.head()
# Out:
#   Tube_Alias Flaw_ID  Angle      Amp_1      Amp_2      Amp_3      Amp_4  \
# 0       AP01       A      0  10.320653  14.854606  16.017633  12.423161
# 1       AP01       A     10   9.256762  13.566036  12.946058  12.594721
# 2       AP01       A     20   6.375396   8.061063   9.746397  10.879743
# 3       AP01       A     30   9.700410  11.746437  14.777542  16.300598
# 4       AP01       A     40   7.913722  10.297010  10.453795  10.156999
#
#        Amp_5      Amp_6      Amp_7  ...  Phase_12  Phase_13  Phase_14  \
# 0  23.971155  18.113805  36.668613  ... -0.874738  1.146718  0.792448
# 1  19.365281  17.401339  28.518174  ... -0.931822  1.134723  0.870461
# 2  14.309066  18.105114  22.923653  ... -0.833733  1.277617  0.792631
# 3  18.984767  21.744765  30.582848  ... -0.967913  1.275743  0.818410
# 4  15.417897  17.797726  26.734713  ... -0.849391  1.286724  0.671175
#
#    Phase_15  Phase_16  Phase_17  Phase_18  Phase_19  Phase_20  Flaw_Depth
# 0  0.330427 -0.038826 -0.681307 -0.840659  0.556654  0.333518       0.076
# 1  0.290231 -0.069128 -0.695486 -0.739280  0.548302  0.294714       0.076
# 2  0.355075 -0.013229 -0.505109 -0.781582  0.626245  0.293746       0.076
# 3  0.338012 -0.003931 -0.437232 -0.721585  0.560389  0.277560       0.076
# 4  0.372874 -0.057453 -0.440830 -0.200000  0.514553  0.194392       0.076
#
# [5 rows x 44 columns]

# %%
new_df2 = mp.subset_data_with_features(df, feature_list=['Amp_10', 'Phase_15'])
new_df2.head()
# Out:
#   Tube_Alias Flaw_ID  Angle     Amp_10  Phase_15  Flaw_Depth
# 0       AP01       A      0  35.139706  0.330427       0.076
# 1       AP01       A     10  33.768920  0.290231       0.076
# 2       AP01       A     20  28.693021  0.355075       0.076
# 3       AP01       A     30  29.467458  0.338012       0.076
# 4       AP01       A     40  22.470982  0.372874       0.076

# %% [markdown]
# ##### The functions also provide the option to drop a random tube alias from the dataframe

# %%
df['Tube_Alias'].unique()
# Out:
# array(['AP01', 'AP02', 'AP03', 'AP04', 'AP05', 'CP01', 'CP02', 'CP03',
#        'CP04', 'CP05', 'RP02', 'RP03', 'RP04', 'RP05', 'RP06', 'WT02',
#        'WT03', 'WT04', 'WT05'], dtype=object)

# %%
new_df3 = mp.exclude_random_tube(df)

# %%
new_df3['Tube_Alias'].unique()
# Out:
# array(['AP02', 'AP03', 'AP04', 'AP05', 'CP01', 'CP02', 'CP03', 'CP04',
#        'CP05', 'RP02', 'RP03', 'RP04', 'RP05', 'RP06', 'WT02', 'WT03',
#        'WT04', 'WT05'], dtype=object)

# %% [markdown]
# ##### You can subset the data based on selecting random angles for each tube/flaw pair. The default value is 1 angle per tube/flaw, but you can choose whatever you like. Below is an example with 2 random angles per tube/flaw.

# %%
new_df4 = mp.pick_random_angle_rows(df, num=2)
new_df4.head()
# Out:
#   Tube_Alias Flaw_ID  Angle      Amp_1      Amp_2      Amp_3      Amp_4  \
# 0       AP01       A    100  15.787986  16.587679  21.951638  17.885413
# 1       AP01       A    170  22.193651  16.478787  34.109705  21.119385
# 2       AP01       B    130  53.610751  39.452027  80.062210  46.077773
# 3       AP01       B    150  55.924986  34.477951  82.233307  49.487226
# 4       AP01       C     60  51.184711  49.003643  77.631193  72.297870
#
#         Amp_5      Amp_6       Amp_7  ...  Phase_15  Phase_16  Phase_17  \
# 0   34.074086  18.358172   51.181806  ...  0.389544 -0.056397 -0.408446
# 1   50.387691  16.670030   79.137553  ...  0.417320 -0.001445 -0.598973
# 2  120.144701   5.429487  194.063681  ...  0.358438  0.029517 -0.626986
# 3  124.884456  12.935593  198.003694  ...  0.390145  0.023867 -0.588234
# 4  116.750740   6.379050  183.565317  ...  0.341692 -0.044112 -0.630663
#
#    Phase_18  Phase_19  Phase_20  Flaw_Depth  Pct_Depth  Flaw_Volume  Flaw_Area
# 0 -0.888428  0.731680  0.344095       0.076       10.3        0.864    11.3288
# 1 -0.780981  0.767024  0.369973       0.076       10.3        0.864    11.3288
# 2 -0.907842  0.810729 -0.121476       0.152       20.6        1.728    11.3288
# 3 -0.883141  0.777585  0.410427       0.152       20.6        1.728    11.3288
# 4 -0.955366  0.723759  0.382473       0.229       31.1        2.592    11.3288
#
# [5 rows x 47 columns]

# %% [markdown]
# ##### Finally, you can choose how the training and test data are split. The first option uses scikit learn's built-in train_test_split method. The default proportion of values in the training set is 0.8, but you can set it to whatever you like.

# %%
training, test = mp.use_train_test_split(df, train_pct=0.75)

# %%
training.head()
# Out:
#   Tube_Alias Flaw_ID  Angle       Amp_1      Amp_2       Amp_3       Amp_4  \
# 0       CP01       D    230  124.850943  75.775265  187.789007  112.553831
# 1       CP03       B     60    8.649198  13.902870   12.814413   10.313041
# 2       CP05       C    150   41.815957  34.824093   63.113117   41.609900
# 3       CP02       A    230   30.866836  19.604668   45.393244   11.395020
# 4       WT03       B    190   13.430420  11.069166   19.080740   13.949902
#
#         Amp_5      Amp_6       Amp_7  ...  Phase_15  Phase_16  Phase_17  \
# 0  284.140218  29.914768  453.175763  ...  0.407731 -0.030815 -0.478661
# 1   17.883506  15.077404   29.097524  ...  0.567622  0.246343 -0.333000
# 2   93.287548  16.123000  149.388996  ...  0.570716  0.057602 -0.328801
# 3   69.412435  11.545175  110.664778  ...  0.485072  0.548024 -0.415244
# 4   27.868707   7.918982   44.596521  ...  0.605633  0.193040 -0.297659
#
#    Phase_18  Phase_19  Phase_20  Flaw_Depth  Pct_Depth  Flaw_Volume  Flaw_Area
# 0 -0.875626  0.807909  0.470828       0.292       39.6        3.313  11.328800
# 1 -0.356707  1.014557  0.806040       0.152       20.6        0.384   2.512200
# 2 -0.887212  0.995189  0.433921       0.216       29.3        1.088   5.016500
# 3 -0.581466  0.601208 -0.499467       0.076       10.3        0.576   7.568400
# 4 -0.752373  1.007591  0.676190       0.142       20.0        0.637   4.483999
#
# [5 rows x 47 columns]

# %%
test.head()
# Out:
#      Tube_Alias Flaw_ID  Angle       Amp_1       Amp_2       Amp_3  \
# 5107       WT03       F     40   51.211427   36.168807   75.747728
# 2393       CP03       G    310   18.296134   16.400545   29.427400
# 3498       RP03       D    150   42.618348   35.248519   64.561995
# 5788       WT05       G    130  211.564204  152.319922  322.094544
# 5249       WT04       A     60    2.126748    8.978530    3.698965
#
#            Amp_4       Amp_5       Amp_6       Amp_7  ...  Phase_15  Phase_16  \
# 5107   45.325434  117.777638   11.392083  189.862060  ...  0.337132 -0.109532
# 2393   27.168372   47.843782   12.754223   76.341804  ...  0.200487 -0.262095
# 3498   41.378838   96.117111   15.903924  151.369418  ...  0.507515  0.015894
# 5788  220.668464  494.019403  293.572238  808.751309  ...  0.265352 -0.692511
# 5249    7.739184    5.794735    6.235919    8.041948  ...  0.322392  0.003046
#
#       Phase_17  Phase_18  Phase_19  Phase_20  Flaw_Depth  Pct_Depth  \
# 5107 -0.559054 -0.982107  0.850765 -0.142226       0.427       60.0
# 2393 -0.622943 -1.108679  0.622381  0.296996       0.521       70.7
# 3498 -0.419556 -0.874365  0.912059  0.447304       0.290       39.4
# 5788 -0.569452 -0.962100  0.854487  0.446323       0.498       70.0
# 5249 -0.108485 -0.913397  0.594888  0.352919       0.071       10.0
#
#       Flaw_Volume  Flaw_Area
# 5107        1.911   4.483999
# 2393        1.312   2.512200
# 3498        1.296   4.483999
# 5788        8.916  17.935994
# 5249        0.563   7.938234
#
# [5 rows x 47 columns]

# %% [markdown]
# ##### Alternatively, you can choose a custom splitter that ensures tube/flaw pairs are not shared between the test/train set. For example, all instances of AP01 with flaw A would show up in either the training set or the test set, but not both.

# %%
training2, test2 = mp.split_tube_flaw_between_train_test(df, train_pct=0.75)

# %%
training2.sort_values(['Tube_Alias', 'Flaw_ID', 'Angle']).head()
# Out:
#      Tube_Alias Flaw_ID  Angle      Amp_1      Amp_2      Amp_3      Amp_4  \
# 2106       AP01       A      0  10.320653  14.854606  16.017633  12.423161
# 63         AP01       A     10   9.256762  13.566036  12.946058  12.594721
# 317        AP01       A     20   6.375396   8.061063   9.746397  10.879743
# 1336       AP01       A     30   9.700410  11.746437  14.777542  16.300598
# 2283       AP01       A     40   7.913722  10.297010  10.453795  10.156999
#
#           Amp_5      Amp_6      Amp_7  ...  Phase_15  Phase_16  Phase_17  \
# 2106  23.971155  18.113805  36.668613  ...  0.330427 -0.038826 -0.681307
# 63    19.365281  17.401339  28.518174  ...  0.290231 -0.069128 -0.695486
# 317   14.309066  18.105114  22.923653  ...  0.355075 -0.013229 -0.505109
# 1336  18.984767  21.744765  30.582848  ...  0.338012 -0.003931 -0.437232
# 2283  15.417897  17.797726  26.734713  ...  0.372874 -0.057453 -0.440830
#
#       Phase_18  Phase_19  Phase_20  Flaw_Depth  Pct_Depth  Flaw_Volume  \
# 2106 -0.840659  0.556654  0.333518       0.076       10.3        0.864
# 63   -0.739280  0.548302  0.294714       0.076       10.3        0.864
# 317  -0.781582  0.626245  0.293746       0.076       10.3        0.864
# 1336 -0.721585  0.560389  0.277560       0.076       10.3        0.864
# 2283 -0.200000  0.514553  0.194392       0.076       10.3        0.864
#
#       Flaw_Area
# 2106    11.3288
# 63      11.3288
# 317     11.3288
# 1336    11.3288
# 2283    11.3288
#
# [5 rows x 47 columns]

# %%
test2.sort_values(['Tube_Alias', 'Flaw_ID', 'Angle']).head()
# Out:
#     Tube_Alias Flaw_ID  Angle      Amp_1      Amp_2      Amp_3      Amp_4  \
# 499       AP01       B      0  36.221091  27.615068  55.197284  31.687575
# 500       AP01       B     10  37.919316  25.727886  55.830544  33.572782
# 501       AP01       B     20  41.675609  20.394822  61.486515  34.094998
# 502       AP01       B     30  36.310727  21.290750  56.400562  41.954908
# 503       AP01       B     40  39.926000  31.871166  59.242943  36.997879
#
#          Amp_5      Amp_6       Amp_7  ...  Phase_15  Phase_16  Phase_17  \
# 499  83.976849  16.687873  131.858595  ...  0.357420 -0.079227 -0.629653
# 500  85.948893   8.328127  139.496115  ...  0.358851 -0.044346 -0.631171
# 501  94.081847   6.742141  152.091663  ...  0.363403  0.009234 -0.633922
# 502  85.279194  15.808790  137.027767  ...  0.365524 -0.001769 -0.622837
# 503  92.233388   7.304527  146.747261  ...  0.362425 -0.013571 -0.625705
#
#      Phase_18  Phase_19  Phase_20  Flaw_Depth  Pct_Depth  Flaw_Volume  \
# 499 -0.941627  0.635804  0.355119       0.152       20.6        1.728
# 500 -0.973232  0.708834  0.344032       0.152       20.6        1.728
# 501 -0.939547  0.667020 -0.106303       0.152       20.6        1.728
# 502 -0.965853  0.723438 -0.177416       0.152       20.6        1.728
# 503 -0.923809  0.707503 -0.053165       0.152       20.6        1.728
#
#      Flaw_Area
# 499    11.3288
# 500    11.3288
# 501    11.3288
# 502    11.3288
# 503    11.3288
#
# [5 rows x 47 columns]

# %% [markdown]
# # Important

# %% [markdown]
# ##### This brings up to how these functions are all put together. Although they can be used individually, they are also packaged into one driver function, which was first shown in cell 4. The driver function has one required parameter, a dataframe, and four optional parameters: feature_list (default is None), method (more on this later), train_pct (default is 0.8), and num (default is 1). feature_list is used to subset the dataframe to include only the features of interest; train_pct is the train/test split desired; and num is the number of random angles if you want that option. method requires a string argument: 'one', 'two', 'three', 'four', 'five', 'six'; the default is 'one'. These strings will select a pre-coded combination of the above options.

# %% [markdown]
# ##### 'one' has no random angle selection, no dropped random tube alias, and uses sklearn's train/test split method.

# %% [markdown]
# ##### 'two' is the same as 'one', but includes the random angle functionality.

# %% [markdown]
# ##### 'three' is the same as 'two', but also drops a random tube alias.

# %% [markdown]
# ##### 'four' has no random angle selection, no dropped random tube alias, and uses the custom train/test split method.

# %% [markdown]
# ##### 'five' is the same as 'four', but includes the random angle functionality.

# %% [markdown]
# ##### 'six' is the same as 'five', but also drops a random tube alias.

# %% [markdown]
# ##### the function below uses method 'five' with 2 random angles per tube/flaw

# %%
X_train, X_test, y_train, y_test, train_df, test_df = mp.get_scaled_training_test_data(df, method='five', num=2)

# %% [markdown]
# ##### train_df and test_df are also output as dataframes so you can check what's actually going on. Note that these are not scaled or appropriate for modeling.

# %%
train_df.sort_values(['Tube_Alias', 'Flaw_ID', 'Angle']).head()
# Out:
#     Tube_Alias Flaw_ID  Angle       Amp_1      Amp_2       Amp_3       Amp_4  \
# 188       AP01       A     40    7.913722  10.297010   10.453795   10.156999
# 161       AP01       A    190   23.663649  18.492380   33.856683   19.007084
# 168       AP01       C    180   82.178030  73.852387  124.424825   91.528220
# 35        AP01       C    210   68.941938  57.190145  103.440970   84.423248
# 127       AP01       E    210  122.832180  88.209231  184.150580  128.420844
#
#           Amp_5       Amp_6       Amp_7  ...  Phase_12  Phase_13  Phase_14  \
# 188   15.417897   17.797726   26.734713  ... -0.849391  1.286724  0.671175
# 161   51.872652   17.542679   82.153486  ... -0.929686  1.274152  0.899454
# 168  186.500312  127.050519  295.666356  ... -1.124231  1.256743  0.817790
# 35   155.080616   21.485233  242.502381  ... -1.107806  1.250887  0.798592
# 127  281.784246   17.981392  451.954580  ... -1.206040  1.123332  0.674553
#
#      Phase_15  Phase_16  Phase_17  Phase_18  Phase_19  Phase_20  Flaw_Depth
# 188  0.372874 -0.057453 -0.440830 -0.200000  0.514553  0.194392       0.076
# 161  0.440365  0.025547 -0.573360 -0.797294  0.795442 -0.167126       0.076
# 168  0.375358 -0.013108 -0.586082 -0.888007  0.718511  0.431480       0.229
# 35   0.367751 -0.020435 -0.594297 -0.920926  0.766144  0.423165       0.229
# 127  0.255989 -0.189128 -0.648784 -0.984664  0.683224  0.383337       0.368
#
# [5 rows x 44 columns]

# %% [markdown]
# ##### you might see that some of the Tube/Flaw pairs only have one example, when we would expect them to have two. This is the result of the evenly_distribute function, which finds the tube/flaw pair with the lowest number of examples, and then randomly selects that same number of examples from the other tube/flaw pairs so that the model training training will not be biased towards a particular flaw size.

# %%
df['Flaw_ID'].value_counts()
# Out:
# H    684
# F    684
# E    684
# D    684
# C    684
# G    684
# B    679
# I    648
# A    452
# Name: Flaw_ID, dtype: int64

# %% [markdown]
# ##### above we can see that flaw A has the few examples.

# %%
evenly_distributed_data = mp.evenly_distribute(df)

# %%
evenly_distributed_data['Flaw_ID'].value_counts()
# Out:
# A    452
# E    452
# B    452
# D    452
# I    452
# H    452
# C    452
# F    452
# G    452
# Name: Flaw_ID, dtype: int64

# %% [markdown]
# ##### after running the evenly_distribute function, we now have equal numbers of flaws for each flaw type.
